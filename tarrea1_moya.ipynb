# %% [markdown]
# ## <center> Modelos y Simulación</center>
# ##### <center>  [Investigación y simulación, Inmunizacion en el Ecuador contra el Covid-19 ]</center>
# <center> [Sexto “B”]</center>
# <center> Desarrollado por:</center>
# <center> Delgado Delgado Gemberth Josue</center>
# <center> [30/06/2021]</center>

# %% [markdown]
# ### Resumen.
# El sars-cov-2 aparecio hace tan solo un año atras, una pandemia que se veia venir segun los cientificos, esto a afectado a la sociedad en generalcausando perdidas humanas, economicas etc, de aqui el gran efuerzo de los gobiernos en comenzar una campaña de vacunacion eficiente y eficas, cosa que no a sido asi en el pais, sin embargo, la administración de dichas vacunas es muy importante para que la sosiedad comienze a recuperarse, por ello debe de existir un adecuado manejo en la inmunizacion de los ciudadanos.Este estudio plantea describir y analizar  si la administración de las vacunas en Ecuador se hace de manera adecuada en los hospitales, centro de salud, describiendo un modelo a partir de los datos, para asi comtribuir en la mejora de algun aspecto de esta gran lavor de inmunizacion.

# %% [markdown]
# ##### Palabras Claves.
# Covid-19, sars-cov-2, Vacunas, Sistema de salud, Modelo estadístico de
# vacunas, Pandemia.

# %% [markdown]
# ### 1. INTRODUCCIÓN

# %% [markdown]
# Los científicos advirtieron hace años que una pandemia era cuestión de tiempo si se seguía contaminando la naturaleza además predijeron, según los datos, que la futura pandemias se originarían en Asia. Así fue como a finales del año 2019 empezó una tragedia que fue predicha hace años atrás, comenzaba la pesadilla del sars-cov-2 o covid-19, un virus que tomo desprevenido al mundo. Las naciones incluido nuestro país ecuador tuvo que acogerse a una nueva normalidad donde estar con personas es sinónimo de peligro, sin dudas esto causo grandes pérdidas tanto económicas como pérdidas humanas, así fue como un gran esfuerzo de científicos y médicos en busca de una vacuna dio frutos, en menos de un año se logro encontrar la cura, a comienzos del 2021 comenzaría la campaña de inmunización más grande en la historia del Ecuador. De aquí nace la necesidad de realizar un estudio que plantea establecer si la inmunización de los ciudadanos  en el  Ecuador se hace de manera adecuada analizando los datos oficiales, para generar modelos estadisticos que permitan facilitar la mejora o toma de desisiones en el sistema de bacunacion del estado conociendo el  porcentaje de personas que han recibido las dos vacunas, es decir, que han generado inmunización.

# %% [markdown]
# ### 2. DESCRIPCIÓN DEL SISTEMA

# %% [markdown]
# El desarrollo del modelo para determinar el avance de la inmunización de la
# sociedad del Ecuador mediante la aplicación de vacunas y el correcto uso de estas, permiten
# determinar como un enfoque global del sistema.
# Partiendo con el Sistema de salud, como el ente prncipal  encargado de administrar el sistema de vaculacion
# , mientras que el servicio complementario o privado de salud, es accesible para
# un determinado sector de la sociedad.
# Dentro del sistema de salud se encuentran los  Hospitales generales y de especialidades , que se encargan de las principales emergencias segun su nivel de especialidad de los pacientes en el n Ecuador, seguido estan los  Centros de salud, que se encargan de descongestionar los grandes hospitalez en atención de primaria o para las personas con dolencias cronicas, de hay las de gravedad se derivan a los Hospitales.
# Por último, el aspecto central del sistema, el Lugar de vacunación, ya que a partir de aquí se
# toman los datos para posteriormente hacer un análisis de estos, y determinar el enfoque de
# este estudio.
# A continuación se detalla de manera global el sistema y su estructura, con la finalidad de
# entender el sistema central delos datos.
# ![sistema%20de%20salud.png](attachment:sistema%20de%20salud.png)
#
#
#
# Como se ve en la figura se pretende definir las variables de  comparación, la primera es el estado
# de vacunación a los pacientes que han recibido la primera dosis de la vacuna, y la segunda
# variable es a los pacientes que han recibido las dos dosis de la vacuna, estas variables serán
# analizadas de esta manera:
# * Personas vacunadas
# * Personas completamente vacunadas.
#
# El tiempo en el que se ejecutará esta investigación serán con los datos de
# vacunación del Ecuador desde el primer trimestre del año  2021, para determinar mejores
# resultados con respecto al inicio de la vacunación.
#
# Se empleará datos estadísticos para determinar los resultados del estudio, también se utilizarán
# gráficos con la finalidad de observar los resultados obtenidos y a partir de allí sustentar los
# mismos, se utilizará Python y sus modulos correspondientes para facilitar el desarrollo del
# sistema y que este nos permita analizar los resultados obtenidos gracias a los datos de la pagina datosmacro.com

# %% [markdown]
# ### 3. ANÁLISIS DE LOS DATOS DE ENTRADA

# %% [markdown]
# Los datos apresentar sobre la vacunacion en el pais son de comienzo del año 2021.
# Estos an sido extraidos de datosmacro.com
#
# ### 3.1 Importamos librerias  y leemos los tatos

# %%
# Importación de las librerías
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# Variable que contiene la fuente de información
URL = 'https://datosmacro.expansion.com/otros/coronavirus-vacuna/ecuador'

# Leemos los datos almacenados en la página web
datos = pd.read_html(URL)
datos
# Out:
# [         Fecha Dosis administradas Personas vacunadas Completamente vacunadas  \
#  0   29/06/2021           4.024.007          2.701.284               1.322.723
#  1   28/06/2021           4.024.007          2.701.284               1.322.723
#  2   27/06/2021           3.991.635          2.680.072               1.311.563
#  3   26/06/2021           3.944.256          2.537.302               1.260.361
#  4   25/06/2021           3.797.663          2.537.302               1.260.361
#  ..         ...                 ...                ...                     ...
#  95  23/03/2021             182.261            143.614                  38.647
#  96  22/03/2021             178.970            140.765                  38.205
#  97  21/03/2021             178.970            140.765                  38.205
#  98  20/03/2021             141.191            121.054                  20.137
#  99  19/03/2021             141.191            121.054                  20.137
#
# ...

# %%
# Presentamos los datos en un Dataframe de Pandas
df = datos[0]
indice = list(range(100))
# Se crea un índice para hacer los gráficos estadísticos
df['Indice'] = indice
# Se visualizan los datos del ultimo mes de vacunacion 
df.head(10)
# Out:
#         Fecha Dosis administradas Personas vacunadas Completamente vacunadas  \
# 0  29/06/2021           4.024.007          2.701.284               1.322.723
# 1  28/06/2021           4.024.007          2.701.284               1.322.723
# 2  27/06/2021           3.991.635          2.680.072               1.311.563
# 3  26/06/2021           3.944.256          2.537.302               1.260.361
# 4  25/06/2021           3.797.663          2.537.302               1.260.361
# 5  24/06/2021           3.797.663          2.537.302               1.260.361
# 6  23/06/2021           3.725.385          2.480.014               1.245.371
# 7  22/06/2021           3.658.226          2.426.450               1.231.776
# 8  21/06/2021           3.580.667          2.368.971               1.211.696
# 9  20/06/2021           3.558.254          2.079.889               1.053.498
#
#   % completamente vacunadas  Indice
# 0                     7,66%       0
# 1                     7,66%       1
# ...

# %%
# Se visualizan los datos de los 10 primeros días de vacunación
df.tail(10)
# Out:
#          Fecha Dosis administradas Personas vacunadas Completamente vacunadas  \
# 90  28/03/2021             235.000            174.642                  60.358
# 91  27/03/2021             235.000            174.642                  60.358
# 92  26/03/2021             230.770            172.413                  58.357
# 93  25/03/2021             191.179            152.526                  38.653
# 94  24/03/2021             191.179            152.526                  38.653
# 95  23/03/2021             182.261            143.614                  38.647
# 96  22/03/2021             178.970            140.765                  38.205
# 97  21/03/2021             178.970            140.765                  38.205
# 98  20/03/2021             141.191            121.054                  20.137
# 99  19/03/2021             141.191            121.054                  20.137
#
#    % completamente vacunadas  Indice
# 90                     0,35%      90
# ...

# %% [markdown]
# ### 3.2 Observacion estadistica de los datos
#
# Aqui tenemos las variables que seran utilizadas para esta investif¡gacion
# * Fecha Dosis administradas Personas
# * Personas vacunadas
# * Personas completamente vacunada
# * % completamente vacunadas

# %% [markdown]
# ### 3.3 Gráfico del Sistema.

# %%
# Variables extraidas a partir del dataframe
p = df.head(15)
m = df.tail(15)
plt.figure(figsize=(15,5))
# Gráfico de las personas completamente vacunadas
plt.subplot(121)
plt.title('Personas completamente vacunadas')
plt.stem(p['Indice'], p['Personas vacunadas'])
# Gráfico de las personas vacunadas
plt.subplot(122)
plt.title('Personas vacunadas')
plt.stem(m['Indice'], m['Completamente vacunadas'])
# Se muestran los gráficos
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7cf9be089569> in <module>
#       6 plt.subplot(121)
#       7 plt.title('Personas completamente vacunadas')
# ----> 8 plt.stem(p['Indice'], p['Personas vacunadas'])
#       9 # Gráfico de las personas vacunadas
#      10 plt.subplot(122)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in stem(linefmt, markerfmt, basefmt, bottom, label, use_line_collection, data, *args)
#    2911         bottom=bottom, label=label,
#    2912         use_line_collection=use_line_collection, **({"data": data} if
# -> 2913         data is not None else {}))
#    2914
#    2915
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
x=datos["Personas vacunadas"]
plt.figure(figsize=(15,5))
plt.hist(x,bins=8,color='blue')
plt.axvline(x.mean(),color='red',label='Media')
plt.axvline(x.median(),color='yellow',label='Mediana')
plt.axvline(x.mode()[0],color='green',label='Moda')
plt.xlabel('Peso de los articulos')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3c3a6911ef47> in <module>
# ----> 1 x=datos["Personas vacunadas"]
#       2 plt.figure(figsize=(15,5))
#       3 plt.hist(x,bins=8,color='blue')
#       4 plt.axvline(x.mean(),color='red',label='Media')
#       5 plt.axvline(x.median(),color='yellow',label='Mediana')
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ### 4. FORMULACIÓN DEL SIMULACIÓN DISCRETA

# %% [markdown]
# ## Analisis

# %%
y= datos["Personas vacunadas"]
x=datos["Completamente vacunadas"]
plt.rcParams["figure.figsze"]=(15,5)
fig, ax =plt.subplots()
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_ytitle('')
plt.bar(x,y,color='c')
plt.show()

# %%
# Variables extraidas a partir del dataframe
p = df.head(15)
m = df.tail(15)
plt.figure(figsize=(15,5))
# Gráfico de las personas completamente vacunadas
plt.subplot(121)
plt.title('Incremento de muertes')
plt.stem(p['Indice'], p['Incremento Muertos'])
# Gráfico de las personas vacunadas
plt.subplot(122)
plt.title('Total de muertes ')
plt.stem(m['Indice'], m['Incremento Confirmados'])
# Se muestran los gráficos

plt.show()

# %% [markdown]
# #### Preparamos el Gráfico
# Utilizamos la biblioteca matplotlib.pyplot.hist(x,bins,Range=None,Color=None....) donde x son los datos que vamos a
# graficar, bins=8 el número de clases, y ademas el color=blue, en el gráfico tambien incorporamos la media xmean() , la
# mediana x.median(), y la moda x.mode()[0], utilizando plt.axvline

# %%
plt.figure(figsize=(15,5))
# Gráfico de las personas completamente vacunadas
plt.subplot(121)
plt.title("Personas completamente vacunadas")
plt.hist(p['Completamente vacunadas'], bins=7, edgecolor='black')
# Gráfico de las personas vacunadas
plt.subplot(122)
plt.title("Personas vacunadas")
plt.hist(m['Personas vacunadas'], bins=7, edgecolor='black')
# Se muestran los gráficos
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Personas completamente vacunadas'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-8deff686f1d9> in <module>
# ...

# %% [markdown]
# ### MEDIDAS DE TENDENCIA CENTRAL
# #### MEDIA, MEDIANA, MODA
# ##### calculo de la media
# Es una medida de uso común, en una muestra de n datos, la media muestra el promedio aritmético simple de los datos
# utilizamos mean() para su calculo

# %% [markdown]
# ### Calculo de la media
# la mediana es el valor ubicado en el centro de los datos ordenados

# %% [markdown]
# ### Calculo de la moda
# La moda es el dato que ocurre con más frecuencia en la muestra, puede existir o no, o también puede existir más de una
# moda

# %%
# ahora mediante el metodo moda() sacamos la moda

# %% [markdown]
# La moda es de 0

# %% [markdown]
# ## Resumen de medidas de tendencia central
# #### los DataFrame de pandas permite entregar un informe completo de todas las medidas de tendencia central utilizando la
# función describe() donde nos presentará todas las medidas de tendencia central Al pareser la moda de consumo de vevidas alcoholicas entre la ceveza detiladas y vinos es de 0

# %%
# Tomamos los datos de las columnas
datos[['beer_servings','spirit_servings','wine_servings']].describe()
# describe(), nos presenta directamente la media, desviación standar, 
#el valor mínimo, valor máximo, el 1er cuartil, 2do Cuartil, 3er Cuartil

# %% [markdown]
# ## Seleccionamos los datos de los primeros 30 paises para  comparar las tases de consumo de alcohol  entre ellos
# Para seleccionar las columnas de un dataframe se usa una sintaxis de rangos por medio de dos puntos `:.[::] Donde:`
# corresponde al índice a partir del cual se iniciará el rango.
# corresponde al índice final del rango, el cual no será incluído en el resultado.
# corresponde al tamaño incrementos/decrementos que se aplicará al rango.
# en el caso de nuestro ejercicio utilizaremos de la siguiente forma

# %%
# seleccionamos los datos de los primeros 30 paises registrados,  para el calculo
df_1 = datos[:30]
print ("Estadisticos del mes de abril")
print ("-----------------------------")
df_1[['beer_servings','spirit_servings','wine_servings']].describe()

# %% [markdown]
# ##### Para calcular las demas naciones delimitamos entre corchetes

# %%
df_2 = datos[30:61]
df_2

# %% [markdown]
# **Igualmente realizamos de la misma forma para el resto de naciones que faltan**

# %%
print ("Estadisticos del mes de Mayo ")
print ("-----------------------------")
df_2[['beer_servings','spirit_servings','wine_servings']].describe()

# %% [markdown]
# # OTROS GRÁFICOS ADICIONALES
# ## Gráficos lineales
# Nos permite mostrar la tendencia de los datos, para el caso del ejercicio el gráfico muestra la tendencia de los datos de
# las semanas del mes por cada una de las variables

# %%
#x = np.arange(61)
x = datos["country"]
t1 = datos["beer_servings"]
t2 = datos["spirit_servings"]
t3 = datos["wine_servings"]
plt.figure(figsize=(14,8))
plt.plot(x,t1,x,t2,x,t3,marker='o')
plt.xlabel('Paises ')
plt.ylabel('Porsiones de alcohol consumidas')
plt.legend(('porciones de cerveza','porciones de bebidas Destiladas', 'porsiones de vino'), prop = {'size':10},loc='upper right')

# %% [markdown]
# ## Gráfico en varias ventanas
# utilizamos subplot para hacer varios cuadros estadístico separadas de diferentes variables del problema. Esto nos
# permite tener una mejor apreciación de los datos

# %%
x = range(193)
plt.figure(figsize=(15,15))
plt.subplot(131)

t1 = datos["beer_servings"]
p1 = plt.plot(x,t1,'r')
plt.ylabel('Alcohol')
plt.title(' Cebeza ')
plt.subplot(132)

t2 = datos["spirit_servings"]
p1 = plt.plot(x,t2,'b')
plt.title(' bebidas destiladas ')
plt.subplot(133)

t3 = datos["total_litres_of_pure_alcohol"]
p1 = plt.plot(x,t3,'g')
plt.title(' Total ')

# %% [markdown]
# ## TABLA DE FRECUENCIAS

# %%
# OBTENER LOS DATOS UNICOS DE LA TABLA
lis = datos["total_litres_of_pure_alcohol"].unique()
lis
dfclases=pd.DataFrame(lis,columns=["total_litres_of_pure_alcohol"])
dfclases

# %% [markdown]
# ## FRECUENCIAS ABSOLUTAS
# La frecuencia absoluta es una medida estadística que nos da información acerca de la cantidad de veces que se repite un suceso al realizar un número determinado de experimentos aleatorios. Esta medida se representa mediante las letras fi. La letra f se refiere a la palabra frecuencia y la letra i se refiere a la realización i-ésima del experimento aleatorio.

# %%
#TABLA DE FRECUENCIAS ABSOLUTAS
# OBTENER FRECUENCIAS ABSOLUTAS DE CADA CLASE
datafi=pd.crosstab(index=datos["total_litres_of_pure_alcohol"], columns = "fi")
# Creamos una lista con los valores de las frecuencias
li = datafi.values
# agregamos una columna al dataframe
dfclases["fi"] = li
#observamos dfclase
dfclases

# %%
total

# %%
 # Columna de Frecuencia relativa
total = dfclases.sum(axis=0)
datahi = dfclases["fi"]/total["fi"] # aqui calculamos la frecuencia
datahi.values
# agregamos nueva columna de frecuencia relativa
dfclases["hi"] = datahi
dfclases

# %%
total1 = dfclases.sum(axis=0) # totales
